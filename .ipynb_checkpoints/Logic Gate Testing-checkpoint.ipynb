# %%
# Imports
from biocrnpyler import *
from genelet import *
import pylab as plt
import numpy as np
from bokeh.layouts import row

import warnings
import bokeh.io
import bokeh.plotting

# %% [markdown]
# ## CRNs
# ### NAND Gate CRN

# %%
# Creating CRN for NAND gate

S1_off = Species("Sw1")
S2_off = Species("Sw2")
S3_off = Species("Sw3")

S1 = Genelet(S1_off, transcript = "I31", activator = "A1", inhibitor = "I1" )
S2 = Genelet(S2_off, transcript = "I32", activator = "A2", inhibitor = "I2" )
S3 = Genelet(S3_off, transcript = "I4", activator = "A31", inhibitor = "I31", activator2 = "A32", inhibitor2 = "I32" )

M_NAND = Mixture(name = "Switch_test", components = [S1,S2,S3], parameter_file = "default_parameters.txt")

repr(M_NAND)
CRN_NAND = M_NAND.compile_crn()
#CRN_NAND.write_sbml_file('NAND_CRN.xml')
#print(CRN_NAND.pretty_print())
# Out:
# Species (33) = {0. Sw1_OFF, 1. complex[Sw1_OFF:dna[A1]], 2. rna[I31], 3. dna[A1], 4. rna[I1], 5. protein[RNAP], 6. protein[RNAseH], 7. complex[rna[I1]:dna[A1]], 8. complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]], 9. complex[Sw1_OFF:protein[RNAP]], 10. complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]], 11. Sw2_OFF, 12. complex[dna[A2]:Sw2_OFF], 13. rna[I32], 14. dna[A2], 15. rna[I2], 16. complex[rna[I2]:dna[A2]], 17. complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]], 18. complex[Sw2_OFF:protein[RNAP]], 19. complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]], 20. Sw3_OFF, 21. complex[dna[A31]:Sw3_OFF], 22. complex[dna[A32]:Sw3_OFF], 23. rna[I4], 24. dna[A31], 25. dna[A32], 26. complex[dna[A31]:rna[I31]], 27. complex[rna[I32]:dna[A32]], 28. complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]], 29. complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]], 30. complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]], 31. complex[Sw3_OFF:protein[RNAP]], 32. complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]]}
# Reactions (34) = [
# 0. Sw1_OFF + dna[A1] --> complex[Sw1_OFF:dna[A1]]
#         massaction: k_f(Sw1_OFF,dna[A1])=0.00394*Sw1_OFF*dna[A1]
# 1. complex[Sw1_OFF:dna[A1]] + rna[I1] --> Sw1_OFF + complex[rna[I1]:dna[A1]]
#         massaction: k_f(complex[Sw1_OFF:dna[A1]],rna[I1])=0.0696*complex[Sw1_OFF:dna[A1]]*rna[I1]
# 2. dna[A1] + rna[I1] --> complex[rna[I1]:dna[A1]]
#         massaction: k_f(dna[A1],rna[I1])=0.0696*dna[A1]*rna[I1]
# 3. complex[Sw1_OFF:dna[A1]] + protein[RNAP] <--> complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]]
#         massaction: k_f(complex[Sw1_OFF:dna[A1]],protein[RNAP])=38.857142857142854*complex[Sw1_OFF:dna[A1]]*protein[RNAP]
#         k_r(complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]])=10.0*complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]]
# 4. complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]] --> complex[Sw1_OFF:dna[A1]] + rna[I31] + protein[RNAP]
#         massaction: k_f(complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]])=0.064*complex[complex[Sw1_OFF:dna[A1]]:protein[RNAP]]
# 5. Sw1_OFF + protein[RNAP] <--> complex[Sw1_OFF:protein[RNAP]]
#         massaction: k_f(Sw1_OFF,protein[RNAP])=9.53047619047619*Sw1_OFF*protein[RNAP]
#         k_r(complex[Sw1_OFF:protein[RNAP]])=10.0*complex[Sw1_OFF:protein[RNAP]]
# 6. complex[Sw1_OFF:protein[RNAP]] --> Sw1_OFF + rna[I31] + protein[RNAP]
#         massaction: k_f(complex[Sw1_OFF:protein[RNAP]])=0.007*complex[Sw1_OFF:protein[RNAP]]
# 7. complex[rna[I1]:dna[A1]] + protein[RNAseH] <--> complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]]
#         massaction: k_f(complex[rna[I1]:dna[A1]],protein[RNAseH])=111.82417582417582*complex[rna[I1]:dna[A1]]*protein[RNAseH]
#         k_r(complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]])=10.0*complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]]
# 8. complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]] --> rna[I1] + protein[RNAseH]
#         massaction: k_f(complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]])=0.176*complex[complex[rna[I1]:dna[A1]]:protein[RNAseH]]
# 9. Sw2_OFF + dna[A2] --> complex[dna[A2]:Sw2_OFF]
#         massaction: k_f(Sw2_OFF,dna[A2])=0.00394*Sw2_OFF*dna[A2]
# 10. complex[dna[A2]:Sw2_OFF] + rna[I2] --> Sw2_OFF + complex[rna[I2]:dna[A2]]
#         massaction: k_f(complex[dna[A2]:Sw2_OFF],rna[I2])=0.0696*complex[dna[A2]:Sw2_OFF]*rna[I2]
# 11. dna[A2] + rna[I2] --> complex[rna[I2]:dna[A2]]
#         massaction: k_f(dna[A2],rna[I2])=0.0696*dna[A2]*rna[I2]
# 12. complex[dna[A2]:Sw2_OFF] + protein[RNAP] <--> complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]]
#         massaction: k_f(complex[dna[A2]:Sw2_OFF],protein[RNAP])=38.857142857142854*complex[dna[A2]:Sw2_OFF]*protein[RNAP]
#         k_r(complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]])=10.0*complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]]
# 13. complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]] --> complex[dna[A2]:Sw2_OFF] + rna[I32] + protein[RNAP]
#         massaction: k_f(complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]])=0.064*complex[complex[dna[A2]:Sw2_OFF]:protein[RNAP]]
# 14. Sw2_OFF + protein[RNAP] <--> complex[Sw2_OFF:protein[RNAP]]
#         massaction: k_f(Sw2_OFF,protein[RNAP])=9.53047619047619*Sw2_OFF*protein[RNAP]
#         k_r(complex[Sw2_OFF:protein[RNAP]])=10.0*complex[Sw2_OFF:protein[RNAP]]
# 15. complex[Sw2_OFF:protein[RNAP]] --> Sw2_OFF + rna[I32] + protein[RNAP]
#         massaction: k_f(complex[Sw2_OFF:protein[RNAP]])=0.007*complex[Sw2_OFF:protein[RNAP]]
# 16. complex[rna[I2]:dna[A2]] + protein[RNAseH] <--> complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]]
#         massaction: k_f(complex[rna[I2]:dna[A2]],protein[RNAseH])=111.82417582417582*complex[rna[I2]:dna[A2]]*protein[RNAseH]
#         k_r(complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]])=10.0*complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]]
# 17. complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]] --> rna[I2] + protein[RNAseH]
#         massaction: k_f(complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]])=0.176*complex[complex[rna[I2]:dna[A2]]:protein[RNAseH]]
# 18. Sw3_OFF + dna[A31] --> complex[dna[A31]:Sw3_OFF]
#         massaction: k_f(Sw3_OFF,dna[A31])=0.00394*Sw3_OFF*dna[A31]
# 19. complex[dna[A31]:Sw3_OFF] + rna[I31] --> Sw3_OFF + complex[dna[A31]:rna[I31]]
#         massaction: k_f(complex[dna[A31]:Sw3_OFF],rna[I31])=0.0696*complex[dna[A31]:Sw3_OFF]*rna[I31]
# 20. dna[A31] + rna[I31] --> complex[dna[A31]:rna[I31]]
#         massaction: k_f(dna[A31],rna[I31])=0.0696*dna[A31]*rna[I31]
# 21. Sw3_OFF + dna[A32] --> complex[dna[A32]:Sw3_OFF]
#         massaction: k_f(Sw3_OFF,dna[A32])=0.00394*Sw3_OFF*dna[A32]
# 22. complex[dna[A32]:Sw3_OFF] + rna[I32] --> Sw3_OFF + complex[rna[I32]:dna[A32]]
#         massaction: k_f(complex[dna[A32]:Sw3_OFF],rna[I32])=0.0696*complex[dna[A32]:Sw3_OFF]*rna[I32]
# 23. dna[A32] + rna[I32] --> complex[rna[I32]:dna[A32]]
#         massaction: k_f(dna[A32],rna[I32])=0.0696*dna[A32]*rna[I32]
# 24. complex[dna[A32]:Sw3_OFF] + protein[RNAP] <--> complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]]
#         massaction: k_f(complex[dna[A32]:Sw3_OFF],protein[RNAP])=38.857142857142854*complex[dna[A32]:Sw3_OFF]*protein[RNAP]
#         k_r(complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]])=10.0*complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]]
# 25. complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]] --> complex[dna[A32]:Sw3_OFF] + rna[I4] + protein[RNAP]
#         massaction: k_f(complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]])=0.064*complex[complex[dna[A32]:Sw3_OFF]:protein[RNAP]]
# 26. complex[rna[I32]:dna[A32]] + protein[RNAseH] <--> complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]]
#         massaction: k_f(complex[rna[I32]:dna[A32]],protein[RNAseH])=111.82417582417582*complex[rna[I32]:dna[A32]]*protein[RNAseH]
#         k_r(complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]])=10.0*complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]]
# 27. complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]] --> rna[I31] + protein[RNAseH]
#         massaction: k_f(complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]])=0.176*complex[complex[rna[I32]:dna[A32]]:protein[RNAseH]]
# 28. complex[dna[A31]:Sw3_OFF] + protein[RNAP] <--> complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]]
#         massaction: k_f(complex[dna[A31]:Sw3_OFF],protein[RNAP])=38.857142857142854*complex[dna[A31]:Sw3_OFF]*protein[RNAP]
#         k_r(complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]])=10.0*complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]]
# 29. complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]] --> complex[dna[A31]:Sw3_OFF] + rna[I4] + protein[RNAP]
#         massaction: k_f(complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]])=0.064*complex[complex[dna[A31]:Sw3_OFF]:protein[RNAP]]
# 30. Sw3_OFF + protein[RNAP] <--> complex[Sw3_OFF:protein[RNAP]]
#         massaction: k_f(Sw3_OFF,protein[RNAP])=9.53047619047619*Sw3_OFF*protein[RNAP]
#         k_r(complex[Sw3_OFF:protein[RNAP]])=10.0*complex[Sw3_OFF:protein[RNAP]]
# 31. complex[Sw3_OFF:protein[RNAP]] --> Sw3_OFF + rna[I4] + protein[RNAP]
#         massaction: k_f(complex[Sw3_OFF:protein[RNAP]])=0.007*complex[Sw3_OFF:protein[RNAP]]
# 32. complex[dna[A31]:rna[I31]] + protein[RNAseH] <--> complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]]
#         massaction: k_f(complex[dna[A31]:rna[I31]],protein[RNAseH])=111.82417582417582*complex[dna[A31]:rna[I31]]*protein[RNAseH]
#         k_r(complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]])=10.0*complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]]
# 33. complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]] --> rna[I31] + protein[RNAseH]
#         massaction: k_f(complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]])=0.176*complex[complex[dna[A31]:rna[I31]]:protein[RNAseH]]
# ]

# %% [markdown]
# ### AND Gate CRN

# %%
S4_off = Species("Sw4")

S4 = Genelet(S4_off, transcript = "P", activator = "A4", inhibitor = "I4" )

M_AND = Mixture(name = "AND_test", components = [S1,S2,S3,S4], parameter_file = "default_parameters.txt")

repr(M_AND)
CRN_AND = M_AND.compile_crn()
#print(CRN_AND.pretty_print())

# %% [markdown]
# ### NOR Gate CRN

# %%
# Creating CRN for NOR gate

S1_off = Species("Sw1")
S2_off = Species("Sw2")
S3_off = Species("Sw3")

S1 = Genelet(S1_off, transcript = "I3", activator = "A1", inhibitor = "I1" )
S2 = Genelet(S2_off, transcript = "I3", activator = "A2", inhibitor = "I2" )
S3 = Genelet(S3_off, transcript = "I4", activator = "A3", inhibitor = "I3" )

M_NOR = Mixture(name = "Switch_test", components = [S1,S2,S3], parameter_file = "default_parameters.txt")

repr(M_NOR)
CRN_NOR = M_NOR.compile_crn()
#print(CRN_NOR.pretty_print())

# %% [markdown]
# ### OR Gate CRN

# %%
S4_off = Species("Sw4")

S4 = Genelet(S4_off, transcript = "P", activator = "A4", inhibitor = "I4" )

M_OR = Mixture(name = "AND_test", components = [S1,S2,S3,S4], parameter_file = "default_parameters.txt")

repr(M_OR)
CRN_OR = M_OR.compile_crn()
#print(CRN_OR.pretty_print())

# %% [markdown]
# ## Simulations
# ### NAND Gate Simulation

# %%
# Bioscrape simulation of above CRN

io = {"Sw1_OFF": 2000, "dna_A1": 2000, "rna_I1": 0, "Sw2_OFF": 2000, "dna_A2": 2000, "rna_I2": 0, "Sw3_OFF":2000, "dna_A31": 2000, "dna_A32": 2000, "protein_RNAseH":20,
      "protein_RNAP":150}
timepoints = np.linspace(0, 5000, 1000)
R = CRN_NAND.simulate_with_bioscrape(timepoints, initial_condition_dict = io)


bokeh.io.output_notebook()
p = bokeh.plotting.figure(plot_width=300, plot_height=300)
p.circle(timepoints, R["Sw1_OFF"], legend_label = "OFF switch 1", color = "orange")
p.circle(timepoints, R["complex_Sw1_ON"], legend_label = "ON switch 1", color = "red")
p.legend.click_policy="hide"


s = bokeh.plotting.figure(plot_width=300, plot_height=300)
s.circle(timepoints, R["Sw2_OFF"], legend_label = "OFF switch 2", color = "orange")
s.circle(timepoints, R["complex_Sw2_ON"], legend_label = "ON switch 2" , color = "red")
s.legend.click_policy="hide"


# Total amount of activated and deactivated forms of Switch 3
q = bokeh.plotting.figure(plot_width=300, plot_height=300)
q.circle(timepoints, R["Sw3_OFF"], legend_label = "OFF switch 3", color = "orange")
q.circle(timepoints, R["complex_Sw3_ON_1"]+R["complex_Sw3_ON_2"], legend_label = "ON switch 3" , color = "red")
q.legend.click_policy="hide"



r = bokeh.plotting.figure(plot_width=300, plot_height=300)
r.circle(timepoints, R["rna_I4"], legend_label = "Inhibitor 4", color = "green")
r.circle(timepoints, R["rna_I31"], legend_label = "Inhibitor 31" , color = "red")
r.circle(timepoints, R["rna_I32"], legend_label = "Inhibitor 32" , color = "blue")
r.circle(timepoints, R["complex_Sw3_AI"], legend_label = "Complex 31", color = "purple")
r.legend.click_policy="hide"

bokeh.io.show(row(p, s, q,r))
warnings.filterwarnings("ignore")
# Out:
# /home/nazmus/anaconda3/lib/python3.7/site-packages/html5lib/_trie/_base.py:3: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping
# /home/nazmus/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/nazmus/anaconda3/lib/python3.7/site-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# odeint failed with mxstep=500...
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="324e164c-f79a-4e4c-b91f-74a13d9ae8b0" data-root-id="1278"></div>

# %%
q = bokeh.plotting.figure(plot_width=300, plot_height=300)
q.circle(timepoints, R["Sw3_OFF"], legend_label = "OFF switch 3", color = "orange")
q.circle(timepoints, R["complex_Sw3_ON_1"], legend_label = "ON switch 3 - 1" , color = "red")
q.circle(timepoints, R["complex_Sw3_ON_2"], legend_label = "ON switch 3 - 2" , color = "blue")
q.legend.click_policy="hide"
bokeh.io.show(q)
# Out:
#   <div class="bk-root" id="ee137352-181c-4181-839f-a9e7a2b109f5" data-root-id="1615"></div>

# %% [markdown]
# ### NOR Gate Simulation

# %%
# Bioscrape simulation of NOR gate CRN

io = {"Sw1_OFF": 2000, "dna_A1": 2000, "rna_I1": 0, "Sw2_OFF": 2000, "dna_A2": 2000, "rna_I2": 0, "Sw3_OFF":2000, "dna_A3": 2000,
      "rna_I3": 0, "protein_RNAseH":10, "protein_RNAP":500}

timepoints = np.linspace(0, 500, 1000)
R = CRN_NOR.simulate_with_bioscrape(timepoints, initial_condition_dict = io)

bokeh.io.output_notebook()
p = bokeh.plotting.figure(plot_width=300, plot_height=300)
p.circle(timepoints, R["Sw1_OFF"], legend_label = "OFF switch 1", color = "orange")
p.circle(timepoints, R["complex_Sw1_ON"], legend_label = "ON switch 1", color = "red")

s = bokeh.plotting.figure(plot_width=300, plot_height=300)
s.circle(timepoints, R["Sw2_OFF"], legend_label = "OFF switch 1", color = "orange")
s.circle(timepoints, R["complex_Sw2_ON"], legend_label = "ON switch 2" , color = "red")

q = bokeh.plotting.figure(plot_width=300, plot_height=300)
q.circle(timepoints, R["Sw3_OFF"], legend_label = "OFF switch 3", color = "orange")
q.circle(timepoints, R["complex_Sw3_ON"], legend_label = "ON switch 3" , color = "red")

bokeh.io.show(row(p, s, q))
warnings.filterwarnings("ignore")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1831">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="03d919f7-e8c3-426e-8e65-b6dd60e675d1" data-root-id="2012"></div>

# %%
# NOR gate activators and inhibitors of importance

bokeh.io.output_notebook()

p = bokeh.plotting.figure(plot_width=300, plot_height=300)
p.circle(timepoints, R["dna_A3"], legend_label = "Activator 3", color = "orange")
p.circle(timepoints, R["rna_I3"], legend_label = "Inhibitor 3", color = "red")
p.circle(timepoints, R["complex_Sw3_AI"], legend_label = "Complex 3", color = "blue")
p.legend.click_policy="hide"

s = bokeh.plotting.figure(plot_width=300, plot_height=300)
s.circle(timepoints, R["rna_I4"], legend_label = "Inhibitor 4", color = "red")
s.legend.click_policy="hide"

bokeh.io.show(row(p, s))
warnings.filterwarnings("ignore")
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2305">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="fec038aa-a55b-44aa-bd91-7639e4b59830" data-root-id="2428"></div>

# %% [markdown]
# ### AND Gate Simulation

# %%
# Bioscrape simulation of above CRN

io = {"Sw1_OFF": 2000, "dna_A1": 2000, "rna_I1": 0, "Sw2_OFF": 2000, "dna_A2": 2000, "rna_I2": 0, "Sw3_OFF":2000, "dna_A31": 2000, "dna_A32": 2000, "protein_RNAseH":20,
      "protein_RNAP":150}
timepoints = np.linspace(0, 5000, 1000)
R = CRN_AND.simulate_with_bioscrape(timepoints, initial_condition_dict = io)


bokeh.io.output_notebook()
p = bokeh.plotting.figure(plot_width=300, plot_height=300)
p.circle(timepoints, R["Sw1_OFF"], legend_label = "OFF switch 1", color = "orange")
p.circle(timepoints, R["complex_Sw1_ON"], legend_label = "ON switch 1", color = "red")
p.legend.click_policy="hide"

s = bokeh.plotting.figure(plot_width=300, plot_height=300)
s.circle(timepoints, R["Sw2_OFF"], legend_label = "OFF switch 2", color = "orange")
s.circle(timepoints, R["complex_Sw2_ON"], legend_label = "ON switch 2" , color = "red")
s.legend.click_policy="hide"

# Total amount of activated and deactivated forms of Switch 3
q = bokeh.plotting.figure(plot_width=300, plot_height=300)
q.circle(timepoints, R["Sw3_OFF"], legend_label = "OFF switch 3", color = "orange")
q.circle(timepoints, R["complex_Sw3_ON_1"]+R["complex_Sw3_ON_2"], legend_label = "ON switch 3" , color = "red")
q.legend.click_policy="hide"

r = bokeh.plotting.figure(plot_width=300, plot_height=300)
r.circle(timepoints, R["rna_I4"], legend_label = "Inhibitor 4", color = "green")
r.circle(timepoints, R["rna_I31"], legend_label = "Inhibitor 31" , color = "red")
r.circle(timepoints, R["rna_I32"], legend_label = "Inhibitor 32" , color = "blue")
r.circle(timepoints, R["complex_Sw3_AI"], legend_label = "Complex 31", color = "purple")
r.legend.click_policy="hide"
bokeh.io.show(row(p, s, q,r))
warnings.filterwarnings("ignore")
# Out:
# odeint failed with mxstep=500...
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2677">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="410d9c48-1beb-4e70-8b3f-3747f3ba73e4" data-root-id="2954"></div>

# %%
q = bokeh.plotting.figure(plot_width=300, plot_height=300)
q.circle(timepoints, R["Sw3_OFF"], legend_label = "OFF switch 3", color = "orange")
q.circle(timepoints, R["complex_Sw3_ON_1"], legend_label = "ON switch 3 - 1" , color = "red")
q.circle(timepoints, R["complex_Sw3_ON_2"], legend_label = "ON switch 3 - 2" , color = "blue")
q.legend.click_policy="hide"

r = bokeh.plotting.figure(plot_width=300, plot_height=300)
r.circle(timepoints, R["rna_I4"], legend_label = "Inhibitor 4", color = "green")
r.circle(timepoints, R["rna_I31"], legend_label = "Inhibitor 31" , color = "red")
r.circle(timepoints, R["rna_I32"], legend_label = "Inhibitor 32" , color = "blue")
r.circle(timepoints, R["complex_Sw3_AI"], legend_label = "Complex 31", color = "purple")
r.legend.click_policy="hide"
bokeh.io.show(row(q, r))
# Out:
#   <div class="bk-root" id="7a5bcd3c-be93-4d0c-a578-839818471098" data-root-id="3580"></div>
